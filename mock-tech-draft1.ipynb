# %%
### I have another notebook where I'm trying to smooth this out and put it into classes
# it's a mess still but I'll upload soon
## I think my problem with approaching these problems is that 
#I try to tackle everything at once instead of taking it step by step sometimes


import requests

data = requests.get('https://ct-mock-tech-assessment.herokuapp.com/').json()


_listocountries=set()
countries=[x['country']for x in data['partners']]

for i in countries:
    _listocountries.add(i)
    
# print(_listocountries)
# {'Japan', 'France', 'United States', 'Singapore', 'Ireland', 'Mexico', 'United Kingdom', 'Spain', 'Canada'}
#should put this all into functions but just rolling with things


uk=[]
for dic in data['partners']:
    if dic['country']=='United Kingdom':
        uk.append(dic)
        
us=[]
for dic in data['partners']:
    if dic['country']=='United States':
        us.append(dic)
        
jp=[]
for dic in data['partners']:
    if dic['country']=='Japan':
        jp.append(dic)
        
fr=[]
for dic in data['partners']:
    if dic['country']=='France':
        fr.append(dic)
        
sing=[]
for dic in data['partners']:
    if dic['country']=='Singapore':
        sing.append(dic)
        
ir=[]
for dic in data['partners']:
    if dic['country']=='Ireland':
        ir.append(dic)
        
mx=[]
for dic in data['partners']:
    if dic['country']=='Mexico':
        mx.append(dic)
        
sp=[]
for dic in data['partners']:
    if dic['country']=='Spain':
        sp.append(dic)
        
ca=[]
for dic in data['partners']:
    if dic['country']=='Canada':
        ca.append(dic)
        
ukdates=[x['availableDates'] for x in uk]
usdates=[x['availableDates'] for x in us]
jpdates=[x['availableDates'] for x in jp]
singdates=[x['availableDates'] for x in sing]
irdates=[x['availableDates'] for x in ir]
frdates=[x['availableDates'] for x in fr]
mxdates=[x['availableDates'] for x in mx]
spdates=[x['availableDates'] for x in sp]
cadates=[x['availableDates'] for x in ca]

#I tried set intersection here first, didn't work because not everyone in groups could attend the same date
#It does seem for most countries lists 2 most common date ranges... 

def commonDates(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    return counter

def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
    return max_key

mostCommon(jpdates)

first=[]
for dic in jp:
    if '2017-06-09' and '2017-06-10' in dic['availableDates']:
        first.append(dic)
      
JPattending = {
    'startDate' : mostCommon(jpdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'Japan',
    'attendees' : [x['email'] for x in first]
}

JPattending
# Out:
# {'startDate': '2017-06-09',
#  'attendeeCount': 16,
#  'country': 'Japan',
#  'attendees': ['kbirenbaum@codingtemple.com',
#   'smallet@codingtemple.com',
#   'oblackwelder@codingtemple.com',
#   'mleckband@codingtemple.com',
#   'laubrey@codingtemple.com',
#   'skoellmann@codingtemple.com',
#   'cgrasso@codingtemple.com',
#   'mpittard@codingtemple.com',
#   'ckollmorgen@codingtemple.com',
#   'thouse@codingtemple.com',
#   'drede@codingtemple.com',
#   'lalway@codingtemple.com',
#   'fpeteet@codingtemple.com',
#   'lnikolas@codingtemple.com',
#   'vcortner@codingtemple.com',
#   'hvazzana@codingtemple.com']}

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key

mostCommon(usdates)

# first=[]
for dic in us:
    if '2017-05-28' and '2017-05-29' in dic['availableDates']:
        first.append(dic)
      
USattending = {
    'startDate' : mostCommon(usdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'United States',
    'attendees' : [x['email'] for x in first]
}

USattending
# Out:
# {'startDate': '2017-05-28',
#  'attendeeCount': 32,
#  'country': 'United States',
#  'attendees': ['kbirenbaum@codingtemple.com',
#   'smallet@codingtemple.com',
#   'oblackwelder@codingtemple.com',
#   'mleckband@codingtemple.com',
#   'laubrey@codingtemple.com',
#   'skoellmann@codingtemple.com',
#   'cgrasso@codingtemple.com',
#   'mpittard@codingtemple.com',
#   'ckollmorgen@codingtemple.com',
#   'thouse@codingtemple.com',
#   'drede@codingtemple.com',
#   'lalway@codingtemple.com',
#   'fpeteet@codingtemple.com',
#   'lnikolas@codingtemple.com',
#   'vcortner@codingtemple.com',
#   'hvazzana@codingtemple.com',
#   'rketring@codingtemple.com',
#   'ccafaro@codingtemple.com',
#   'mlacau@codingtemple.com',
#   'eomersa@codingtemple.com',
#   'ssheahan@codingtemple.com',
#   'msoult@codingtemple.com',
#   'bleeks@codingtemple.com',
#   'lsolid@codingtemple.com',
#   'bwatton@codingtemple.com',
#   'jmasher@codingtemple.com',
#   'afernadez@codingtemple.com',
# ...

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key
# mostCommon(frdates)

first=[]
for dic in fr:
    if '2017-06-08' and '2017-06-09' in dic['availableDates']:
        first.append(dic)
      
FRattending = {
    'startDate' : mostCommon(frdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'France',
    'attendees' : [x['email'] for x in first]
}

FRattending
# Out:
# {'startDate': '2017-06-25',
#  'attendeeCount': 17,
#  'country': 'France',
#  'attendees': ['efallick@codingtemple.com',
#   'wkissner@codingtemple.com',
#   'ecantatore@codingtemple.com',
#   'vrindal@codingtemple.com',
#   'nbeau@codingtemple.com',
#   'jgarafola@codingtemple.com',
#   'bdurke@codingtemple.com',
#   'jtopp@codingtemple.com',
#   'tgrush@codingtemple.com',
#   'tpinela@codingtemple.com',
#   'jdefore@codingtemple.com',
#   'jeffner@codingtemple.com',
#   'csibille@codingtemple.com',
#   'agimble@codingtemple.com',
#   'dmaneafaiga@codingtemple.com',
#   'dvosburg@codingtemple.com',
#   'jmacareno@codingtemple.com']}

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key
# 
# mostCommon(singdates)

first=[]
for dic in sing:
    if '2017-06-03' and '2017-06-04' in dic['availableDates']:
        first.append(dic)
      
SINGattending = {
    'startDate' : mostCommon(singdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'Singapore',
    'attendees' : [x['email'] for x in first]
}

SINGattending
# Out:
# {'startDate': '2017-06-03',
#  'attendeeCount': 17,
#  'country': 'Singapore',
#  'attendees': ['mskrobacki@codingtemple.com',
#   'bchiappetta@codingtemple.com',
#   'vgoldhirsh@codingtemple.com',
#   'jkuester@codingtemple.com',
#   'prushford@codingtemple.com',
#   'jnovakovich@codingtemple.com',
#   'ctraut@codingtemple.com',
#   'skriger@codingtemple.com',
#   'yniedzwiecki@codingtemple.com',
#   'imoala@codingtemple.com',
#   'jmolzahn@codingtemple.com',
#   'rdreyfuss@codingtemple.com',
#   'wpreast@codingtemple.com',
#   'dhaselhuhn@codingtemple.com',
#   'hboles@codingtemple.com',
#   'sgallardo@codingtemple.com',
#   'egeis@codingtemple.com']}

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key

mostCommon(irdates)

first=[]
for dic in ir:
    if '2017-05-28' and '2017-05-29' in dic['availableDates']:
        first.append(dic)
      
IRattending = {
    'startDate' : mostCommon(irdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'Ireland',
    'attendees' : [x['email'] for x in first]
}

IRattending
# Out:
# {'startDate': '2017-05-28',
#  'attendeeCount': 15,
#  'country': 'Ireland',
#  'attendees': ['sterrence@codingtemple.com',
#   'dpatnode@codingtemple.com',
#   'enawwar@codingtemple.com',
#   'pbertog@codingtemple.com',
#   'rguldemond@codingtemple.com',
#   'rfarlee@codingtemple.com',
#   'elaskin@codingtemple.com',
#   'greif@codingtemple.com',
#   'mclawson@codingtemple.com',
#   'mbottenfield@codingtemple.com',
#   'akulju@codingtemple.com',
#   'cscoby@codingtemple.com',
#   'dsiebenthal@codingtemple.com',
#   'dharriet@codingtemple.com',
#   'mcrossen@codingtemple.com']}

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key

# mostCommon(mxdates)

first=[]
for dic in mx:
    if '2017-04-19' and '2017-04-20' in dic['availableDates']:
        first.append(dic)
      
MXattending = {
    'startDate' : mostCommon(mxdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'Mexico',
    'attendees' : [x['email'] for x in first]
}

MXattending
# Out:
# {'startDate': '2017-04-19',
#  'attendeeCount': 15,
#  'country': 'Mexico',
#  'attendees': ['sbrugliera@codingtemple.com',
#   'crupprecht@codingtemple.com',
#   'ltoepperwein@codingtemple.com',
#   'faceveda@codingtemple.com',
#   'adanza@codingtemple.com',
#   'otreworgy@codingtemple.com',
#   'bparmele@codingtemple.com',
#   'ghilkert@codingtemple.com',
#   'ymikhaiel@codingtemple.com',
#   'mdelarme@codingtemple.com',
#   'vchenevert@codingtemple.com',
#   'amolinini@codingtemple.com',
#   'triopel@codingtemple.com',
#   'fmaier@codingtemple.com',
#   'bkuligowski@codingtemple.com']}

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key

# mostCommon(spdates)

first=[]
for dic in sp:
    if '2017-04-16' and '2017-04-17' in dic['availableDates']:
        first.append(dic)
      
SPattending = {
    'startDate' : mostCommon(spdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'Spain',
    'attendees' : [x['email'] for x in first]
}

SPattending
# Out:
# {'startDate': '2017-04-16',
#  'attendeeCount': 17,
#  'country': 'Spain',
#  'attendees': ['oduttinger@codingtemple.com',
#   'tzavesky@codingtemple.com',
#   'alyme@codingtemple.com',
#   'mtalton@codingtemple.com',
#   'aferkovich@codingtemple.com',
#   'cbrookhouse@codingtemple.com',
#   'mselk@codingtemple.com',
#   'amacneil@codingtemple.com',
#   'jplants@codingtemple.com',
#   'devora@codingtemple.com',
#   'bcustis@codingtemple.com',
#   'labbot@codingtemple.com',
#   'oalampi@codingtemple.com',
#   'vodien@codingtemple.com',
#   'alema@codingtemple.com',
#   'civery@codingtemple.com',
#   'dheckler@codingtemple.com']}

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key

# mostCommon(cadates)

first=[]
for dic in ca:
    if '2017-06-23' and '2017-06-24' in dic['availableDates']:
        first.append(dic)
      
CAattending = {
    'startDate' : mostCommon(cadates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'Canada',
    'attendees' : [x['email'] for x in first]
}

CAattending
# Out:
# {'startDate': '2017-06-23',
#  'attendeeCount': 14,
#  'country': 'Canada',
#  'attendees': ['rrojero@codingtemple.com',
#   'nshier@codingtemple.com',
#   'tdevoll@codingtemple.com',
#   'lgritton@codingtemple.com',
#   'elizarrago@codingtemple.com',
#   'ehartly@codingtemple.com',
#   'mhutley@codingtemple.com',
#   'rveyna@codingtemple.com',
#   'abending@codingtemple.com',
#   'agewant@codingtemple.com',
#   'csabori@codingtemple.com',
#   'jtrieger@codingtemple.com',
#   'rradoslovich@codingtemple.com',
#   'manglebrandt@codingtemple.com']}

# %%
test=[]
test.append(CAattending)
test.append(USattending)
# test.append(UKattending)
test.append(IRattending)
test.append(SPattending)
test.append(MXattending)
test.append(FRattending)
test.append(SINGattending)
test.append(JPattending)

# %%
test
# Out:
# [{'startDate': '2017-06-23',
#   'attendeeCount': 14,
#   'country': 'Canada',
#   'attendees': ['rrojero@codingtemple.com',
#    'nshier@codingtemple.com',
#    'tdevoll@codingtemple.com',
#    'lgritton@codingtemple.com',
#    'elizarrago@codingtemple.com',
#    'ehartly@codingtemple.com',
#    'mhutley@codingtemple.com',
#    'rveyna@codingtemple.com',
#    'abending@codingtemple.com',
#    'agewant@codingtemple.com',
#    'csabori@codingtemple.com',
#    'jtrieger@codingtemple.com',
#    'rradoslovich@codingtemple.com',
#    'manglebrandt@codingtemple.com']},
#  {'startDate': '2017-05-28',
#   'attendeeCount': 32,
#   'country': 'United States',
#   'attendees': ['kbirenbaum@codingtemple.com',
#    'smallet@codingtemple.com',
#    'oblackwelder@codingtemple.com',
#    'mleckband@codingtemple.com',
#    'laubrey@codingtemple.com',
#    'skoellmann@codingtemple.com',
#    'cgrasso@codingtemple.com',
#    'mpittard@codingtemple.com',
#    'ckollmorgen@codingtemple.com',
# ...

# %%
def mostCommon(lst):
    flatList = [el for sublist in lst for el in sublist]
    counter = {}
    for date in flatList:
        if date in counter:
            counter[date] += 1
        else:
            counter[date] = 1
    max_key = max(counter, key=counter.get)
#     return counter
    return max_key

# mostCommon(ukdates)

first=[]
for dic in uk:
    if '2017-06-01' and '2017-06-02' in dic['availableDates']:
        first.append(dic)
      
UKattending = {
    'startDate' : mostCommon(ukdates),
    'attendeeCount' : len([x['email'] for x in first]),
    'country' : 'United Kingdom',
    'attendees' : [x['email'] for x in first]
}

UKattending
# Out:
# {'startDate': '2017-06-01',
#  'attendeeCount': 16,
#  'country': 'United Kingdom',
#  'attendees': ['arosentrater@codingtemple.com',
#   'jgoettsche@codingtemple.com',
#   'nbehal@codingtemple.com',
#   'bkilcher@codingtemple.com',
#   'ostutler@codingtemple.com',
#   'emaohu@codingtemple.com',
#   'jbattistoni@codingtemple.com',
#   'ccoryea@codingtemple.com',
#   'gcintron@codingtemple.com',
#   'scorlett@codingtemple.com',
#   'dallocca@codingtemple.com',
#   'dneedler@codingtemple.com',
#   'lsachez@codingtemple.com',
#   'sszabo@codingtemple.com',
#   'smaleck@codingtemple.com',
#   'jholtrop@codingtemple.com']}

# %%
test.append(UKattending)
conference={}
conference['partners']=test
conference
# Out:
# {'partners': [{'startDate': '2017-06-23',
#    'attendeeCount': 14,
#    'country': 'Canada',
#    'attendees': ['rrojero@codingtemple.com',
#     'nshier@codingtemple.com',
#     'tdevoll@codingtemple.com',
#     'lgritton@codingtemple.com',
#     'elizarrago@codingtemple.com',
#     'ehartly@codingtemple.com',
#     'mhutley@codingtemple.com',
#     'rveyna@codingtemple.com',
#     'abending@codingtemple.com',
#     'agewant@codingtemple.com',
#     'csabori@codingtemple.com',
#     'jtrieger@codingtemple.com',
#     'rradoslovich@codingtemple.com',
#     'manglebrandt@codingtemple.com']},
#   {'startDate': '2017-05-28',
#    'attendeeCount': 32,
#    'country': 'United States',
#    'attendees': ['kbirenbaum@codingtemple.com',
#     'smallet@codingtemple.com',
#     'oblackwelder@codingtemple.com',
#     'mleckband@codingtemple.com',
#     'laubrey@codingtemple.com',
#     'skoellmann@codingtemple.com',
#     'cgrasso@codingtemple.com',
#     'mpittard@codingtemple.com',
# ...

# %%
#grrrr arrrrghh
# I'm guesing the date range options have something to do with, *bangs head into wall*

# %%
r = requests.post(url = 'https://ct-mock-tech-assessment.herokuapp.com/', data = conference)
  
pastebin_url = r.text
print("The pastebin URL is:%s"%pastebin_url)
# Out:
# The pastebin URL is:<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>500 Internal Server Error</title>
# <h1>Internal Server Error</h1>
# <p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>
